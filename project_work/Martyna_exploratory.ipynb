# %%
import pandas as pd

# Load the dataset
file_path_1 = '/Users/martyna/dev/iron hack/labs/project-1-ironhack-payments-2-en/project_dataset/extract - fees - data analyst - .csv'
file_path_2 = '/Users/martyna/dev/iron hack/labs/project-1-ironhack-payments-2-en/project_dataset/extract - cash request - data analyst.csv'
df_fees = pd.read_csv(file_path_1)
df_cash = pd.read_csv(file_path_2)

# %%
df_fees
# Out:
#           id  cash_request_id             type    status  \
# 0       6537          14941.0  instant_payment  rejected
# 1       6961          11714.0         incident  accepted
# 2      16296          23371.0  instant_payment  accepted
# 3      20775          26772.0  instant_payment  accepted
# 4      11242          19350.0  instant_payment  accepted
# ...      ...              ...              ...       ...
# 21056  12372          20262.0  instant_payment  rejected
# 21057  20768          26764.0  instant_payment  rejected
# 21058  18779          25331.0  instant_payment  rejected
# 21059  16542          23628.0  instant_payment  rejected
# 21060  13301          20982.0  instant_payment  accepted
#
#                     category  total_amount  \
# 0                        NaN           5.0
# 1      rejected_direct_debit           5.0
# 2                        NaN           5.0
# 3                        NaN           5.0
# 4                        NaN           5.0
# ...

# %%
df_cash
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id                   moderated_at  \
# ...

# %%
df_cash.describe()
# Out:
#                  id        amount        user_id  deleted_account_id
# count  23970.000000  23970.000000   21867.000000         2104.000000
# mean   13910.966124     82.720818   32581.250789         9658.755228
# std     7788.117214     26.528065   27618.565773         7972.743249
# min        3.000000      1.000000      34.000000           91.000000
# 25%     7427.250000     50.000000   10804.000000         3767.000000
# 50%    14270.500000    100.000000   23773.000000         6121.500000
# 75%    20607.750000    100.000000   46965.000000        16345.000000
# max    27010.000000    200.000000  103719.000000        30445.000000

# %%
df_fees.isna().sum()
# Out:
# id                     0
# cash_request_id        4
# type                   0
# status                 0
# category           18865
# total_amount           0
# reason                 0
# created_at             0
# updated_at             0
# paid_at             5530
# from_date          13295
# to_date            13295
# charge_moment          0
# dtype: int64

# %%
#counting occurences per user_id, desc
df_cash["user_id"].value_counts()
# Out:
# user_id
# 3377.0     19
# 2142.0     18
# 13851.0    18
# 2530.0     17
# 1159.0     17
#            ..
# 4938.0      1
# 79289.0     1
# 74036.0     1
# 57112.0     1
# 64517.0     1
# Name: count, Length: 10798, dtype: int64

# %%
#counting occurences per user_id, desc, only when status ='money_back'
df_cash[df_cash["status"] == "money_back"]["user_id"].value_counts()
# Out:
# user_id
# 526.0      11
# 274.0      11
# 1946.0     11
# 1381.0     10
# 1795.0     10
#            ..
# 99970.0     1
# 71176.0     1
# 88313.0     1
# 47219.0     1
# 64517.0     1
# Name: count, Length: 8987, dtype: int64

# %%
df_cash["status"].unique()
# Out:
# array(['rejected', 'money_back', 'canceled', 'active',
#        'direct_debit_rejected', 'transaction_declined',
#        'direct_debit_sent'], dtype=object)

# %%
df_cash["status"].value_counts()
# Out:
# status
# money_back               16397
# rejected                  6568
# direct_debit_rejected      831
# active                      59
# transaction_declined        48
# direct_debit_sent           34
# canceled                    33
# Name: count, dtype: int64

# %%
df_cash[df_cash["user_id"] == 526]
# Out:
#           id  amount                status                     created_at  \
# 5822     614    50.0            money_back  2020-02-05 17:54:50.727851+00
# 6528   15856   100.0              rejected  2020-09-12 12:32:13.702831+00
# 6573   16070   100.0            money_back    2020-09-14 13:13:07.2519+00
# 6631   15995   100.0              rejected  2020-09-13 22:54:23.288454+00
# 6654   16025   100.0              rejected  2020-09-14 09:09:50.959096+00
# 7869     824    60.0            money_back   2020-03-08 14:01:05.14633+00
# 7971     131    90.0            money_back  2019-12-12 20:59:48.763947+00
# 8373   20625    90.0  transaction_declined  2020-10-12 14:23:15.276958+00
# 9165    1348    80.0            money_back  2020-04-23 18:54:05.810157+00
# 9194     985    90.0            money_back  2020-03-25 02:27:41.780578+00
# 9533    3478    80.0            money_back  2020-06-16 12:38:38.140763+00
# 12476   7250    90.0            money_back  2020-07-08 22:46:36.854214+00
# ...

# %%
#saving CR ids for the testing, based on one high volume user
check_cr = df_cash[df_cash["user_id"] == 526]["id"]

# %%
check_cr
# Out:
# 5822       614
# 6528     15856
# 6573     16070
# 6631     15995
# 6654     16025
# 7869       824
# 7971       131
# 8373     20625
# 9165      1348
# 9194       985
# 9533      3478
# 12476     7250
# 14483    12484
# 21451    20665
# 21620    26720
# Name: id, dtype: int64

# %%
type(check_cr)
# Out:
# pandas.core.series.Series

# %%
#checking which fees correspond to CRs from customer 526
df_fees[df_fees['id'].isin(check_cr)]
# Out:
#           id  cash_request_id             type     status  \
# 1293     131           2561.0         postpone   accepted
# 1710     824           5600.0         postpone   accepted
# 2009    1348           7193.0         postpone   accepted
# 4624   12484          20363.0  instant_payment   accepted
# 4828    7250          15705.0  instant_payment   accepted
# 5016   15995          23113.0  instant_payment   accepted
# 5106   20625          24848.0         postpone  cancelled
# 5877   16025          23148.0  instant_payment   accepted
# 6263   20665          19201.0         postpone   accepted
# 7189   16070          23196.0  instant_payment   accepted
# 16302    614           4956.0         postpone  cancelled
# 16493    985           1746.0         postpone  cancelled
# 17246  15856          22987.0  instant_payment   accepted
# 20668   3478           8476.0         incident   rejected
#
#                     category  total_amount  \
# 1293                     NaN           5.0
# ...

# %%
#checking how many CR ids from fees match with CR file
df_fees[df_fees['cash_request_id'].isin(df_cash['id'])]
# Out:
#           id  cash_request_id             type    status  \
# 0       6537          14941.0  instant_payment  rejected
# 1       6961          11714.0         incident  accepted
# 2      16296          23371.0  instant_payment  accepted
# 3      20775          26772.0  instant_payment  accepted
# 4      11242          19350.0  instant_payment  accepted
# ...      ...              ...              ...       ...
# 21056  12372          20262.0  instant_payment  rejected
# 21057  20768          26764.0  instant_payment  rejected
# 21058  18779          25331.0  instant_payment  rejected
# 21059  16542          23628.0  instant_payment  rejected
# 21060  13301          20982.0  instant_payment  accepted
#
#                     category  total_amount  \
# 0                        NaN           5.0
# 1      rejected_direct_debit           5.0
# 2                        NaN           5.0
# 3                        NaN           5.0
# 4                        NaN           5.0
# ...

# %%
df_fees.describe()
# Out:
#                  id  cash_request_id  total_amount
# count  21061.000000     21057.000000  21061.000000
# mean   10645.355111     16318.449162      5.000237
# std     6099.315256      6656.149949      0.034453
# min        1.000000      1456.000000      5.000000
# 25%     5385.000000     11745.000000      5.000000
# 50%    10652.000000     17160.000000      5.000000
# 75%    15925.000000     21796.000000      5.000000
# max    21193.000000     27010.000000     10.000000

# %%
df_cash.describe()
# Out:
#                  id        amount        user_id  deleted_account_id
# count  23970.000000  23970.000000   21867.000000         2104.000000
# mean   13910.966124     82.720818   32581.250789         9658.755228
# std     7788.117214     26.528065   27618.565773         7972.743249
# min        3.000000      1.000000      34.000000           91.000000
# 25%     7427.250000     50.000000   10804.000000         3767.000000
# 50%    14270.500000    100.000000   23773.000000         6121.500000
# 75%    20607.750000    100.000000   46965.000000        16345.000000
# max    27010.000000    200.000000  103719.000000        30445.000000

# %%
#checking how many CR ids from fees don't match with CR file
# 2628 rows are missing 
df_fees[~df_fees['cash_request_id'].isin(df_cash['id'])]
# Out:
#          id  cash_request_id             type     status category  \
# 1911   2990              NaN  instant_payment  cancelled      NaN
# 1960   3124              NaN  instant_payment  cancelled      NaN
# 4605   5185              NaN  instant_payment  cancelled      NaN
# 11870  3590              NaN  instant_payment  cancelled      NaN
#
#        total_amount                              reason  \
# 1911            5.0  Instant Payment Cash Request 11164
# 1960            5.0  Instant Payment Cash Request 11444
# 4605            5.0  Instant Payment Cash Request 11788
# 11870           5.0  Instant Payment Cash Request 12212
#
#                           created_at                     updated_at paid_at  \
# 1911   2020-08-06 22:42:34.525373+00  2020-11-04 16:01:17.296048+00     NaN
# 1960   2020-08-08 06:33:06.244651+00  2020-11-04 16:01:08.332978+00     NaN
# 4605   2020-08-26 09:39:37.362933+00  2020-11-04 16:01:36.492576+00     NaN
# ...

# %%
#checking how many CR ids from CR match with fees
df_cash[df_cash['id'].isin(df_fees['cash_request_id'])]
# Out:
#           id  amount                 status                     created_at  \
# 48     23534    25.0             money_back  2020-10-23 15:20:26.163927+00
# 88      2203   100.0             money_back   2020-05-27 02:26:27.61519+00
# 141     6098   100.0                 active   2020-07-01 09:30:03.14541+00
# 143     3611   100.0  direct_debit_rejected   2020-06-17 11:03:32.61712+00
# 161    20639    50.0             money_back  2020-10-12 16:05:27.478409+00
# ...      ...     ...                    ...                            ...
# 23965  20616   100.0             money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0             money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0             money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0             money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0      direct_debit_sent  2020-10-08 14:16:52.155661+00
#
# ...

# %%
#checking how many CR ids from CR don't match with fees
df_cash[~df_cash['id'].isin(df_fees['cash_request_id'])]
# Out:
#           id  amount      status                     created_at  \
# 0          5   100.0    rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0    rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0    rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0    rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0    rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...         ...                            ...
# 23876  26400   100.0  money_back  2020-10-30 14:38:34.863026+00
# 23882  26141    50.0  money_back  2020-10-29 15:30:51.171923+00
# 23889  21841    50.0  money_back  2020-10-17 17:00:51.815205+00
# 23897   4800   100.0  money_back  2020-06-23 11:54:07.112716+00
# 23955   6969   100.0  money_back  2020-07-07 18:11:10.840836+00
#
#                           updated_at  user_id                   moderated_at  \
# 0       2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# ...

# %%
df_cash.describe()
# Out:
#                  id        amount        user_id  deleted_account_id
# count  23970.000000  23970.000000   21867.000000         2104.000000
# mean   13910.966124     82.720818   32581.250789         9658.755228
# std     7788.117214     26.528065   27618.565773         7972.743249
# min        3.000000      1.000000      34.000000           91.000000
# 25%     7427.250000     50.000000   10804.000000         3767.000000
# 50%    14270.500000    100.000000   23773.000000         6121.500000
# 75%    20607.750000    100.000000   46965.000000        16345.000000
# max    27010.000000    200.000000  103719.000000        30445.000000

# %%
df_merged = df_cash.merge(df_fees, how ='left', left_on = ('id'),right_on= ('cash_request_id'))

# %%
df_merged.describe()
# Out:
#                id_x        amount        user_id  deleted_account_id  \
# count  32094.000000  32094.000000   29522.000000         2573.000000
# mean   13822.217424     83.516514   31936.772576        10978.060241
# std     7416.239319     25.900244   26401.062842         8305.770856
# min        3.000000      1.000000      34.000000           91.000000
# 25%     7800.000000     50.000000   11499.000000         4071.000000
# 50%    14115.000000    100.000000   23823.000000         7652.000000
# 75%    19936.000000    100.000000   45419.000000        19540.000000
# max    27010.000000    200.000000  103719.000000        30445.000000
#
#                id_y  cash_request_id  total_amount
# count  21057.000000     21057.000000  21057.000000
# mean   10646.670228     16318.449162      5.000237
# std     6099.136169      6656.149949      0.034457
# min        1.000000      1456.000000      5.000000
# 25%     5388.000000     11745.000000      5.000000
# ...

# %%
#checking for CR id duplicates in fees file 
df_fees["cash_request_id"].value_counts()
# Out:
# cash_request_id
# 12225.0    35
# 5006.0     28
# 4410.0     24
# 12452.0    23
# 11376.0    21
#            ..
# 24822.0     1
# 26203.0     1
# 22956.0     1
# 23207.0     1
# 25331.0     1
# Name: count, Length: 12933, dtype: int64

# %%
#checking for statuses in fees
df_fees["status"].value_counts()
# Out:
# status
# accepted     14841
# cancelled     4938
# rejected      1194
# confirmed       88
# Name: count, dtype: int64

# %%
#total fees by CR request df
df_fees_agg_revenue = df_fees[df_fees["status"] == 'accepted'].groupby("cash_request_id")["total_amount"].sum()

# %%
#cohort attempt
df_cash.head()
# Out:
#      id  amount    status                     created_at  \
# 0     5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0  rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0  rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0  rejected  2020-05-06 09:59:38.877376+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 3  2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 4   2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
#
#    deleted_account_id             reimbursement_date  \
# 0                 NaN  2020-01-09 19:05:21.596363+00
# 1                 NaN   2020-01-09 19:50:12.34778+00
# ...

# %%
df_cash.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23970 entries, 0 to 23969
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          23970 non-null  int64
#  1   amount                      23970 non-null  float64
#  2   status                      23970 non-null  object
#  3   created_at                  23970 non-null  object
#  4   updated_at                  23970 non-null  object
#  5   user_id                     21867 non-null  float64
#  6   moderated_at                16035 non-null  object
#  7   deleted_account_id          2104 non-null   float64
#  8   reimbursement_date          23970 non-null  object
#  9   cash_request_received_date  16289 non-null  object
#  10  money_back_date             16543 non-null  object
#  11  transfer_type               23970 non-null  object
#  12  send_at                     16641 non-null  object
# ...

# %%
df_cash.drop(columns = ["cohort_month"])
# Out:
#           id  amount             status                     created_at  \
# 0          5   100.0           rejected  2019-12-10 19:05:21.596873+00
# 1         70   100.0           rejected   2019-12-10 19:50:12.34778+00
# 2          7   100.0           rejected   2019-12-10 19:13:35.82546+00
# 3         10    99.0           rejected  2019-12-10 19:16:10.880172+00
# 4       1594   100.0           rejected  2020-05-06 09:59:38.877376+00
# ...      ...     ...                ...                            ...
# 23965  20616   100.0         money_back  2020-10-12 13:54:11.686225+00
# 23966  25243    50.0         money_back   2020-10-27 14:41:25.73491+00
# 23967  22357   100.0         money_back  2020-10-20 07:58:04.006937+00
# 23968  20256   100.0         money_back  2020-10-10 05:40:55.700422+00
# 23969  19886   100.0  direct_debit_sent  2020-10-08 14:16:52.155661+00
#
#                           updated_at  user_id                   moderated_at  \
# ...

# %%
df_cash["created_month"] = df_cash["created_at"].str[:7] + "-01"

# %%
df_cash.head()
# Out:
#      id  amount    status                     created_at  \
# 0     5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0  rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0  rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0  rejected  2020-05-06 09:59:38.877376+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 3  2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 4   2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
#
#    deleted_account_id             reimbursement_date  \
# 0                 NaN  2020-01-09 19:05:21.596363+00
# 1                 NaN   2020-01-09 19:50:12.34778+00
# ...

# %%
df_cash["created_month"] = df_cash["created_month"].astype("datetime64[s]")

# %%
df_cash.drop(columns = ["created_month","cohort_month"],inplace=True)

# %%
df_cash.drop(columns = ["cohort_month"],inplace=True)

# %%
df_user_cohort = df_cash.groupby("user_id")["created_month"].min()

# %%
#df_cash["cohort_month"] = df_cash.groupby("user_id")["created_month"].min()

df_cash["cohort_month"] = df_cash["user_id"].map(df_cash.groupby("user_id")["created_month"].min())

# %%
df_cash.head()
# Out:
#      id  amount    status                     created_at  \
# 0     5   100.0  rejected  2019-12-10 19:05:21.596873+00
# 1    70   100.0  rejected   2019-12-10 19:50:12.34778+00
# 2     7   100.0  rejected   2019-12-10 19:13:35.82546+00
# 3    10    99.0  rejected  2019-12-10 19:16:10.880172+00
# 4  1594   100.0  rejected  2020-05-06 09:59:38.877376+00
#
#                       updated_at  user_id                   moderated_at  \
# 0   2019-12-11 16:47:42.40783+00    804.0  2019-12-11 16:47:42.405646+00
# 1  2019-12-11 14:24:22.900054+00    231.0  2019-12-11 14:24:22.897988+00
# 2  2019-12-11 09:46:59.779773+00    191.0  2019-12-11 09:46:59.777728+00
# 3  2019-12-18 14:26:18.136163+00    761.0  2019-12-18 14:26:18.128407+00
# 4   2020-05-07 09:21:55.34008+00   7686.0  2020-05-07 09:21:55.320193+00
#
#    deleted_account_id             reimbursement_date  \
# 0                 NaN  2020-01-09 19:05:21.596363+00
# 1                 NaN   2020-01-09 19:50:12.34778+00
# ...

# %%
df_cash["cohort_month"] = df_cash["cohort_month"].dt.to_period("M")
df_cash["created_month"] = df_cash["created_month"].dt.to_period("M")

# %%
from datetime import datetime as dt
from dateutil.relativedelta import relativedelta

# %%
df_cash["cohort_index"] = (df_cash["created_month"] - df_cash["cohort_month"]).astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 df_cash["cohort_index"] = (df_cash["created_month"] - df_cash["cohort_month"]).astype(int)
#
# File ~/dev/iron hack/Week 1/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~/dev/iron hack/Week 1/.venv/lib/python3.12/site-packages/pandas/core/internals/managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df_cash["cohort_index"] = (df_cash["created_month"].dt.to_period("M") - df_cash["cohort_month"].dt.to_period("M"))

# %%
df_cash[df_cash["user_id"] == 526]
# Out:
#           id  amount                status                     created_at  \
# 5822     614    50.0            money_back  2020-02-05 17:54:50.727851+00
# 6528   15856   100.0              rejected  2020-09-12 12:32:13.702831+00
# 6573   16070   100.0            money_back    2020-09-14 13:13:07.2519+00
# 6631   15995   100.0              rejected  2020-09-13 22:54:23.288454+00
# 6654   16025   100.0              rejected  2020-09-14 09:09:50.959096+00
# 7869     824    60.0            money_back   2020-03-08 14:01:05.14633+00
# 7971     131    90.0            money_back  2019-12-12 20:59:48.763947+00
# 8373   20625    90.0  transaction_declined  2020-10-12 14:23:15.276958+00
# 9165    1348    80.0            money_back  2020-04-23 18:54:05.810157+00
# 9194     985    90.0            money_back  2020-03-25 02:27:41.780578+00
# 9533    3478    80.0            money_back  2020-06-16 12:38:38.140763+00
# 12476   7250    90.0            money_back  2020-07-08 22:46:36.854214+00
# ...

# %%
df_cash["created_month"].dt.to_period("M")
df_cash["cohort_month"].dt.to_period("M")
(df["created_month"] -df["cohort_month"]).astype(int)

# %%
df_cash["cohort_index_test"] = ((df_cash["created_month"].dt.to_period("M") - df_cash["cohort_month"].dt.to_period("M"))).astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df_cash["cohort_index_test"] = ((df_cash["created_month"].dt.to_period("M") - df_cash["cohort_month"].dt.to_period("M"))).astype(int)
#
# File ~/dev/iron hack/Week 1/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...

# %%
df_cash.dtypes
# Out:
# id                                    int64
# amount                              float64
# status                               object
# created_at                           object
# updated_at                           object
# user_id                             float64
# moderated_at                         object
# deleted_account_id                  float64
# reimbursement_date                   object
# cash_request_received_date           object
# money_back_date                      object
# transfer_type                        object
# send_at                              object
# recovery_status                      object
# reco_creation                        object
# reco_last_update                     object
# created_month                 datetime64[s]
# cohort_month                  datetime64[s]
# cohort_index                         object
# cohort_index_test                     int64
# dtype: object

# %%
df_cash_new = df_cash.copy()

# %%
df_cash_new["created_month"] = df_cash_new["created_month"].fillna(pd.Period("1900-01", freq="M"))
df_cash_new["cohort_month"] = df_cash_new["cohort_month"].fillna(pd.Period("1900-01", freq="M"))

# %%
df_cash_new.dtypes
# Out:
# id                                int64
# amount                          float64
# status                           object
# created_at                       object
# updated_at                       object
# user_id                         float64
# moderated_at                     object
# deleted_account_id              float64
# reimbursement_date               object
# cash_request_received_date       object
# money_back_date                  object
# transfer_type                    object
# send_at                          object
# recovery_status                  object
# reco_creation                    object
# reco_last_update                 object
# created_month                 period[M]
# cohort_month                  period[M]
# cohort_index                     object
# cohort_index_test                 int64
# dtype: object

# %%
print(df_cash_new.isna().sum())
# Out:
# id                                0
# amount                            0
# status                            0
# created_at                        0
# updated_at                        0
# user_id                        2103
# moderated_at                   7935
# deleted_account_id            21866
# reimbursement_date                0
# cash_request_received_date     7681
# money_back_date                7427
# transfer_type                     0
# send_at                        7329
# recovery_status               20640
# reco_creation                 20640
# reco_last_update              20640
# created_month                     0
# cohort_month                   2103
# cohort_index                   2103
# cohort_index_test                 0
# dtype: int64

# %%
df_cash_new["cohort_index"] = (df_cash_new["created_month"] - df_cash_new["cohort_month"]).astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df_cash_new["cohort_index"] = (df_cash_new["created_month"] - df_cash_new["cohort_month"]).astype(int)
#
# File ~/dev/iron hack/Week 1/.venv/lib/python3.12/site-packages/pandas/core/generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# ...
